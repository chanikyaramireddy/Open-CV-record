# %% [markdown]
# <a href="https://colab.research.google.com/github/chanikyaramireddy/Open-CV-record/blob/main/Exp1_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
